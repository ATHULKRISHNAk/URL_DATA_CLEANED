# %%
import chardet
with open(r"D:\Dataset\URL\verified_online\verified_online.csv", 'rb') as rawdata:                              
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'MacRoman', 'confidence': 0.7245620437956204, 'language': ''}

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv(r"D:\Dataset\URL\verified_online\verified_online.csv", encoding='MacRoman')

# %%
df
# Out:
#        phish_id                                                url  \
# 0       9025462  https://nos.cv/nosxadmin/szwxfgqu/affinity-acc...
# 1       9025461                https://peaq.netlify.app/connection
# 2       9025460  https://at-t-online-service-s-school1.teachabl...
# 3       9025459  http://at-t-online-service-s-school1.teachable...
# 4       9025458  https://www.detroitautosale.com/wp-content/ai1...
# ...         ...                                                ...
# 65975   3573703   http://www.ezblox.site/free/jennifer111/helpdesk
# 65976   2042606  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...
# 65977   1865971  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...
# 65978   1460953       http://www.habbocreditosparati.blogspot.com/
# 65979   1123978  http://creditiperhabbogratissicuro100.blogspot...
#
#                                         phish_detail_url  \
# 0      http://www.phishtank.com/phish_detail.php?phis...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65980 entries, 0 to 65979
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phish_id           65980 non-null  int64
#  1   url                65980 non-null  object
#  2   phish_detail_url   65980 non-null  object
#  3   submission_time    65980 non-null  object
#  4   verified           65980 non-null  object
#  5   verification_time  65980 non-null  object
#  6   online             65980 non-null  object
#  7   target             65980 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 4.0+ MB

# %%
list(df.columns.values)
# Out:
# ['phish_id',
#  'url',
#  'phish_detail_url',
#  'submission_time',
#  'verified',
#  'verification_time',
#  'online',
#  'target']

# %%
columns_to_drop = ['phish_id','phish_detail_url',
 'submission_time', 'verification_time',
 'online',
 'target']
df = df.drop(columns= columns_to_drop)
df.columns
df.isnull().sum()
# Out:
# url         0
# verified    0
# dtype: int64

# %%
df
# Out:
#                                                      url verified
# 0      https://nos.cv/nosxadmin/szwxfgqu/affinity-acc...      yes
# 1                    https://peaq.netlify.app/connection      yes
# 2      https://at-t-online-service-s-school1.teachabl...      yes
# 3      http://at-t-online-service-s-school1.teachable...      yes
# 4      https://www.detroitautosale.com/wp-content/ai1...      yes
# ...                                                  ...      ...
# 65975   http://www.ezblox.site/free/jennifer111/helpdesk      yes
# 65976  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...      yes
# 65977  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...      yes
# 65978       http://www.habbocreditosparati.blogspot.com/      yes
# 65979  http://creditiperhabbogratissicuro100.blogspot...      yes
#
# [65980 rows x 2 columns]

# %%
df['type'] = df['verified'].replace({'yes': 'phishing'})

# %%
df
# Out:
#                                                      url verified      type
# 0      https://nos.cv/nosxadmin/szwxfgqu/affinity-acc...      yes  phishing
# 1                    https://peaq.netlify.app/connection      yes  phishing
# 2      https://at-t-online-service-s-school1.teachabl...      yes  phishing
# 3      http://at-t-online-service-s-school1.teachable...      yes  phishing
# 4      https://www.detroitautosale.com/wp-content/ai1...      yes  phishing
# ...                                                  ...      ...       ...
# 65975   http://www.ezblox.site/free/jennifer111/helpdesk      yes  phishing
# 65976  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...      yes  phishing
# 65977  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...      yes  phishing
# 65978       http://www.habbocreditosparati.blogspot.com/      yes  phishing
# 65979  http://creditiperhabbogratissicuro100.blogspot...      yes  phishing
#
# [65980 rows x 3 columns]

# %%
df = df.drop(columns=['verified'])

# %%
df
# Out:
#                                                      url      type
# 0      https://nos.cv/nosxadmin/szwxfgqu/affinity-acc...  phishing
# 1                    https://peaq.netlify.app/connection  phishing
# 2      https://at-t-online-service-s-school1.teachabl...  phishing
# 3      http://at-t-online-service-s-school1.teachable...  phishing
# 4      https://www.detroitautosale.com/wp-content/ai1...  phishing
# ...                                                  ...       ...
# 65975   http://www.ezblox.site/free/jennifer111/helpdesk  phishing
# 65976  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...  phishing
# 65977  http://www.formbuddy.com/cgi-bin/formdisp.pl?u...  phishing
# 65978       http://www.habbocreditosparati.blogspot.com/  phishing
# 65979  http://creditiperhabbogratissicuro100.blogspot...  phishing
#
# [65980 rows x 2 columns]

# %%
df.to_csv(r"D:\Dataset\URL\verified_online\verified_online_cleaned1.csv", index=False)
