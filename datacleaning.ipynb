# %%
pip install pandas

# %%
pip install chardet

# %%
import chardet
with open('D:\phishing_detection_api\Phising_dataset.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv('D:\phishing_detection_api\Phising_dataset.csv', encoding='ISO-8859-1')     
df
# Out:
#                                                     URL  Having @ Symbol  \
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...                1
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...                1
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA                1
# 3            https://resicorphome.com/brian/srr/austin/                1
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...                1
# ...                                                 ...              ...
# 1395                               http://csmonitor.com                1
# 1396                                     http://cmu.edu                1
# 1397                              http://greenpeace.org                1
# 1398                            http://entrepreneur.com                1
# 1399                                      http://qz.com                1
#
#       Presence of IP Address  Length of URL  No. of Slashes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   URL                            1400 non-null   object
#  1   Having @ Symbol                1400 non-null   int64
#  2   Presence of IP Address         1400 non-null   int64
#  3   Length of URL                  1400 non-null   int64
#  4   No. of Slashes                 1400 non-null   int64
#  5   Special Character              1400 non-null   int64
#  6   No.of Dots                     1400 non-null   int64
#  7   No. of Hyphen in Host Address  1400 non-null   int64
#  8   "Email" Keyword                1400 non-null   int64
#  9   TLS                            1400 non-null   int64
#  10  Age of URL                     1400 non-null   int64
#  11  Result                         1400 non-null   int64
# dtypes: int64(11), object(1)
# ...

# %%
df.columns
# Out:
# Index(['url', 'type'], dtype='object')

# %%
columns_to_drop = ['Having @ Symbol', 'Presence of IP Address', 'Length of URL',
       'No. of Slashes', 'Special Character', 'No.of Dots',
       'No. of Hyphen in Host Address', '"Email" Keyword', 'TLS ',
       'Age of URL']
df = df.drop(columns= columns_to_drop)
df.columns
df.isnull().sum()
# Out:
# URL       0
# Result    0
# dtype: int64

# %%
df
# Out:
#                                                     URL  Result
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...      -1
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...      -1
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA      -1
# 3            https://resicorphome.com/brian/srr/austin/      -1
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...      -1
# ...                                                 ...     ...
# 1395                               http://csmonitor.com       1
# 1396                                     http://cmu.edu       1
# 1397                              http://greenpeace.org       1
# 1398                            http://entrepreneur.com       1
# 1399                                      http://qz.com       1
#
# [1400 rows x 2 columns]

# %%
df['Results'] = df['Result'].replace({-1: 'phishing', 1: 'legitimate'})

# %%
df
# Out:
#                                                     URL  Result     Results
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...      -1    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...      -1    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA      -1    phishing
# 3            https://resicorphome.com/brian/srr/austin/      -1    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...      -1    phishing
# ...                                                 ...     ...         ...
# 1395                               http://csmonitor.com       1  legitimate
# 1396                                     http://cmu.edu       1  legitimate
# 1397                              http://greenpeace.org       1  legitimate
# 1398                            http://entrepreneur.com       1  legitimate
# 1399                                      http://qz.com       1  legitimate
#
# [1400 rows x 3 columns]

# %%
df.to_csv("D:\phishing_detection_api\Phising_dataset_cleaned.csv", index=False)

# %%
df = df.drop(columns= 'Result')

# %%
df
# Out:
#                                                     URL     Results
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [1400 rows x 2 columns]

# %%
df.to_csv("D:\phishing_detection_api\Phising_dataset_cleaned.csv", index=False)

# %%
df.to_csv("Phising_dataset_cleaned.csv", index=False)

# %%
df.drop_duplicates()
# Out:
#                                                     URL     Results
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [679 rows x 2 columns]

# %%
df.to_csv("D:\phishing_detection_api\Phising_dataset_cleaned_1.csv", index=False)

# %%
df.to_csv("Phising_dataset_cleaned.csv", index=False)

# %%
df
# Out:
#                                                     URL     Results
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [1400 rows x 2 columns]

# %%
df = df.rename(columns={"Results": "type"})

# %%
df
# Out:
#                                                     URL        type
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [1400 rows x 2 columns]

# %%
df.to_csv("D:\phishing_detection_api\Phising_dataset_cleaned_1.csv", index=False)

# %%
df.to_csv("Phising_dataset_cleaned.csv", index=False)

# %%
df
# Out:
#                                                     URL        type
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [1400 rows x 2 columns]

# %%
df = df.rename(columns={"URL": "url"})

# %%
df
# Out:
#                                                     url        type
# 0     https://pogodasub.com/2Ge6I0rd/4p0OksK6-inteli...    phishing
# 1     https://pogodasub.com/2Ge6I0rd/Ly6I98Se-ipko/l...    phishing
# 2                https://pogodasub.com/2Ge6I0rd/hz6hZnA    phishing
# 3            https://resicorphome.com/brian/srr/austin/    phishing
# 4     https://kurier24-oplata.com/PzVxLK7l/WdJslUDi-...    phishing
# ...                                                 ...         ...
# 1395                               http://csmonitor.com  legitimate
# 1396                                     http://cmu.edu  legitimate
# 1397                              http://greenpeace.org  legitimate
# 1398                            http://entrepreneur.com  legitimate
# 1399                                      http://qz.com  legitimate
#
# [1400 rows x 2 columns]

# %%
df.to_csv("D:\phishing_detection_api\Phising_dataset_cleaned_1.csv", index=False)
df.to_csv("Phising_dataset_cleaned.csv", index=False)
